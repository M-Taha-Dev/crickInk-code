# %%
import pandas as pd
df = pd.read_csv('./prd1.csv')

# %%
# Summary statistics for numeric columns
print(df.describe())

# Visualize distribution of runs scored
flag = False
for column in df.columns:
    if column != 'Bowlers_Name' and df[column].dtype == 'object':  # Check if the column is categorical
        plt.figure(figsize=(10, 6))
        df[column].value_counts().plot(kind='bar', color='skyblue')
        plt.title(f'Bar Chart for {column}')
        plt.xlabel(column)
        plt.ylabel('Count')
        plt.xticks(rotation=45)
        plt.tight_layout()
        plt.show()
# Out:
#        OverNumber        Runs
# count  929.000000  929.000000
# mean     8.681808    1.410118
# std      4.959811    1.447629
# min      0.300000   -1.000000
# 25%      4.000000    1.000000
# 50%      8.000000    1.000000
# 75%     12.200000    2.000000
# max     20.000000    6.000000
